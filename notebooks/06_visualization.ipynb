# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import pandas as pd

from src.config import TRANSFORMED_DATA_DIR

features_and_targets = pd.read_parquet(TRANSFORMED_DATA_DIR / "tabular_data.parquet")

# %%
features = features_and_targets.iloc[:, :-1]
targets = features_and_targets["target"]

# %%
features[features['pickup_location_id']==43]
# Out:
#        rides_t-648  rides_t-647  rides_t-646  rides_t-645  rides_t-644  \
# 13858           92           81           29           15            4
# 13859            2            0            2            2            0
# 13860            1            0            0            0            1
# 13861            3            2            0            0            1
# 13862            6            0            0            1            0
# ...            ...          ...          ...          ...          ...
# 14191            6            2            2            0            1
# 14192           20            7            2            0            3
# 14193           10            8            3            1            3
# 14194           19           10            1            2            2
# 14195            4            2            0            1            2
#
#        rides_t-643  rides_t-642  rides_t-641  rides_t-640  rides_t-639  ...  \
# 13858            4            3           12           12           23  ...
# 13859            1            5           10           16           29  ...
# 13860            4           17           49           54           52  ...
# 13861            1           11           51           50           60  ...
# 13862            2           10           61           62           66  ...
# ...            ...          ...          ...          ...          ...  ...
# 14191            7            8           58           84           90  ...
# 14192            3           13           54           67           90  ...
# 14193            0            8           19           35           67  ...
# 14194            3            2           23           28           64  ...
# 14195            3           11           60           81           89  ...
#
#        rides_t-8  rides_t-7  rides_t-6  rides_t-5  rides_t-4  rides_t-3  \
# 13858        162        166        132        159        121         66
# 13859        227        198        114        149         98         42
# 13860        175         97         57         35         28         16
# 13861        145        104         99         74         50         33
# 13862        156        106         88         80         49         43
# ...          ...        ...        ...        ...        ...        ...
# 14191        205        132         64         49         44         31
# 14192         97         57         73         29         48         42
# 14193        239        128         73         52         50         43
# 14194        200        185        160        133        158         69
# 14195        192        173        144        111        133         78
#
#        rides_t-2  rides_t-1  pickup_hour  pickup_location_id
# 13858         47         34   2023-01-28                  43
# 13859         38         37   2023-01-29                  43
# 13860         17         10   2023-01-30                  43
# 13861         16         16   2023-01-31                  43
# 13862         34         13   2023-02-01                  43
# ...          ...        ...          ...                 ...
# 14191         14         10   2023-12-27                  43
# 14192         24          7   2023-12-28                  43
# 14193         30         17   2023-12-29                  43
# 14194         33         19   2023-12-30                  43
# 14195         39         28   2023-12-31                  43
#
# [338 rows x 650 columns]

# %%
from src.plot_utils import plot_aggregated_time_series

plot_aggregated_time_series(features, targets, row_id=3772)
